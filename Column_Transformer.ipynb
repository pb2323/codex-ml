# %% [markdown]
# <a href="https://colab.research.google.com/github/pb2323/codex-ml/blob/main/Column_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer

transformer = ColumnTransformer(transformers=[
    ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
    ('tnf3', SimpleImputer(strategy='constant'), ['fever']),
    ('tnf1', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])
], remainder='passthrough')

# %%
from sklearn.model_selection import train_test_split

X_Train, X_Test, Y_Train, Y_Test = train_test_split(df.drop(columns=['has_covid']), df['has_covid'], test_size=0.2)

# %%
X_Train = transformer.fit_transform(X_Train)
X_Test = transformer.transform(X_Test)

# %%
X_Train.shape
# Out:
# (80, 7)

# %%
X_Train_pd = pd.DataFrame(X_Train)
X_Train_pd.head()
# Out:
#      0      1    2    3    4    5     6
# 0  0.0   98.0  1.0  1.0  0.0  0.0  83.0
# 1  1.0  102.0  0.0  1.0  0.0  0.0  33.0
# 2  0.0   99.0  1.0  1.0  0.0  0.0  65.0
# 3  0.0  102.0  0.0  0.0  0.0  0.0  69.0
# 4  1.0    0.0  1.0  0.0  1.0  0.0  71.0
